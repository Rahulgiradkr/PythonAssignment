# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("Online Retail (3).xlsx - Online Retail.csv")
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# creating copy of data frame

# %%
df1 = df.copy()
df1
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# Analysng given data

# %%
df1.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
df1.shape
# Out:
# (541909, 8)

# %%
df1.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %% [markdown]
# thus there is null values in Description and CustomerID column

# %%
df1.head(20)
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5     536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6     536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7     536366     22633               HAND WARMER UNION JACK         6
# 8     536366     22632            HAND WARMER RED POLKA DOT         6
# 9     536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
# 10    536367     22745           POPPY'S PLAYHOUSE BEDROOM          6
# 11    536367     22748            POPPY'S PLAYHOUSE KITCHEN         6
# ...

# %%
df1.tail(20)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 541889    581585     22466       FAIRY TALE COTTAGE NIGHT LIGHT        12
# 541890    581586     22061  LARGE CAKE STAND  HANGING STRAWBERY         8
# 541891    581586     23275     SET OF 3 HANGING OWLS OLLIE BEAK        24
# 541892    581586     21217        RED RETROSPOT ROUND CAKE TINS        24
# 541893    581586     20685                DOORMAT RED RETROSPOT        10
# 541894    581587     22631             CIRCUS PARADE LUNCH BOX         12
# 541895    581587     22556       PLASTERS IN TIN CIRCUS PARADE         12
# 541896    581587     22555            PLASTERS IN TIN STRONGMAN        12
# 541897    581587     22728            ALARM CLOCK BAKELIKE PINK         4
# 541898    581587     22727            ALARM CLOCK BAKELIKE RED          4
# 541899    581587     22726           ALARM CLOCK BAKELIKE GREEN         4
# 541900    581587     22730           ALARM CLOCK BAKELIKE IVORY         4
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %% [markdown]
# # Analysing invoice column

# %%
df1["InvoiceNo"].unique()
# Out:
# array(['536365', '536366', '536367', ..., '581585', '581586', '581587'],
#       dtype=object)

# %%
df1["InvoiceNo"].nunique()
# Out:
# 25900

# %% [markdown]
# thus there is 25900 unique values

# %%
df2 = df1[df1['InvoiceNo'].str.contains('C')]

# %%
df2
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# thus we have 9288 entry having C thus we have to remov that

# %%
df1["InvoiceNo"] = df1["InvoiceNo"].str.replace("C"," ") 
df1
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# checking is C is removed or not

# %%
df1 = df1[df1['InvoiceNo'].str.contains('C')]
df1
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %% [markdown]
# thus we have 0 entry in this column hece C is removed

# %% [markdown]
# # Analysing for column “CustomerID'

# %%
df1['CustomerID'].isnull().sum()
# Out:
# 0

# %%
df1.describe()
# Out:
#        Quantity  UnitPrice  CustomerID
# count       0.0        0.0         0.0
# mean        NaN        NaN         NaN
# std         NaN        NaN         NaN
# min         NaN        NaN         NaN
# 25%         NaN        NaN         NaN
# 50%         NaN        NaN         NaN
# 75%         NaN        NaN         NaN
# max         NaN        NaN         NaN

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   InvoiceNo    0 non-null      object
#  1   StockCode    0 non-null      object
#  2   Description  0 non-null      object
#  3   Quantity     0 non-null      int64
#  4   InvoiceDate  0 non-null      object
#  5   UnitPrice    0 non-null      float64
#  6   CustomerID   0 non-null      float64
#  7   Country      0 non-null      object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 0.0+ bytes

# %%
df1.isnull().sum()
# Out:
# InvoiceNo      0.0
# StockCode      0.0
# Description    0.0
# Quantity       0.0
# InvoiceDate    0.0
# UnitPrice      0.0
# CustomerID     0.0
# Country        0.0
# dtype: float64

# %%
df2 = df.copy()

# %%
df2
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df2[df2['InvoiceNo'].str.contains('C')]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df2["InvoiceNo"] = df2["InvoiceNo"].str.replace("C"," ") 
df2
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df2[df2['InvoiceNo'].str.contains('C')]
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %% [markdown]
# # Analysing for column “CustomerID'

# %%
df2['CustomerID'].isnull().sum()
# Out:
# 135080

# %%
#Replacing nul values with 0.
df2["CustomerID"].fillna(0,inplace=True)

# %%
# checking whether null values replaced successfully or not
df2[df2["CustomerID"]==0]
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 622       536414     22139                              NaN        56
# 1443      536544     21773  DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444      536544     21774  DECORATIVE CATS BATHROOM BOTTLE         2
# 1445      536544     21786               POLKADOT RAIN HAT          4
# 1446      536544     21787            RAIN PONCHO RETROSPOT         2
# ...          ...       ...                              ...       ...
# 541536    581498    85099B          JUMBO BAG RED RETROSPOT         5
# 541537    581498    85099C   JUMBO  BAG BAROQUE BLACK WHITE         4
# 541538    581498     85150    LADIES & GENTLEMEN METAL SIGN         1
# 541539    581498     85174                S/4 CACTI CANDLES         1
# 541540    581498       DOT                   DOTCOM POSTAGE         1
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 622     12/1/10 11:52       0.00         0.0  United Kingdom
# ...

# %%
# checking the numbers of null values in it.
df2["CustomerID"].isnull().sum()
# Out:
# 0

# %% [markdown]
# thus null values is replaced by zero

# %% [markdown]
# # (4) Analysing for column “Quantity”

# %%
df2["Quantity"].isnull().sum()
# Out:
# 0

# %%
df2["Quantity"].unique()
# Out:
# array([     6,      8,      2,     32,      3,      4,     24,     12,
#            48,     18,     20,     36,     80,     64,     10,    120,
#            96,     23,      5,      1,     -1,     50,     40,    100,
#           192,    432,    144,    288,    -12,    -24,     16,      9,
#           128,     25,     30,     28,      7,     56,     72,    200,
#           600,    480,     -6,     14,     -2,     11,     33,     13,
#            -4,     -5,     -7,     -3,     70,    252,     60,    216,
#           384,    -10,     27,     15,     22,     19,     17,     21,
#            34,     47,    108,     52,  -9360,    -38,     75,    270,
#            42,    240,     90,    320,   1824,    204,     69,    -36,
#          -192,   -144,    160,   2880,   1400,     39,    -48,    -50,
#            26,   1440,     31,     82,     78,     97,     98,     35,
#            57,    -20,    110,    -22,    -30,    -70,   -130,    -80,
# ...

# %%
df2["Quantity"].nunique()
# Out:
# 722

# %% [markdown]
# thus replacing negative by zero

# %%
df2.loc[df2["Quantity"]<0,'Quantity']=0

# %%
df2['Quantity'].unique()
# Out:
# array([    6,     8,     2,    32,     3,     4,    24,    12,    48,
#           18,    20,    36,    80,    64,    10,   120,    96,    23,
#            5,     1,     0,    50,    40,   100,   192,   432,   144,
#          288,    16,     9,   128,    25,    30,    28,     7,    56,
#           72,   200,   600,   480,    14,    11,    33,    13,    70,
#          252,    60,   216,   384,    27,    15,    22,    19,    17,
#           21,    34,    47,   108,    52,    75,   270,    42,   240,
#           90,   320,  1824,   204,    69,   160,  2880,  1400,    39,
#           26,  1440,    31,    82,    78,    97,    98,    35,    57,
#          110,   720,   156,   324,    38,    37,    49,    95,    29,
#           41,   402,   378,   150,   300,    54,   104,    67,   258,
#           66,    44,    55,    46,    99,    61,   408,   972,   208,
#         1008,  1000,  1488,   250,  1394,   400,    79,    84,   272,
# ...

# %% [markdown]
# thus sucessfully replaced by zero

# %% [markdown]
# # Analysing description column

# %%
 # removing the special characters from the Description column
df2['Description'] = df2['Description'].str.replace(r'[^\w\s]', ' ', regex=True)

# %%
df2.loc[120:]
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 120       536381    37444A  YELLOW BREAKFAST CUP AND SAUCER         1
# 121       536381    37444C   PINK BREAKFAST CUP AND SAUCER          1
# 122       536381     22086  PAPER CHAIN KIT 50 S CHRISTMAS          4
# 123       536381     22083        PAPER CHAIN KIT RETROSPOT         1
# 124       536381    84971S        SMALL HEART FLOWERS HOOK          6
# ...          ...       ...                              ...       ...
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 120      12/1/10 9:41       2.95     15311.0  United Kingdom
# ...

# %%
#checking is there any null value or not in it.
df2[df2['Description'].isnull()]
# Out:
#        InvoiceNo StockCode Description  Quantity    InvoiceDate  UnitPrice  \
# 622       536414     22139         NaN        56  12/1/10 11:52        0.0
# 1970      536545     21134         NaN         1  12/1/10 14:32        0.0
# 1971      536546     22145         NaN         1  12/1/10 14:33        0.0
# 1972      536547     37509         NaN         1  12/1/10 14:33        0.0
# 1987      536549    85226A         NaN         1  12/1/10 14:34        0.0
# ...          ...       ...         ...       ...            ...        ...
# 535322    581199     84581         NaN         0  12/7/11 18:26        0.0
# 535326    581203     23406         NaN        15  12/7/11 18:31        0.0
# 535332    581209     21620         NaN         6  12/7/11 18:35        0.0
# 536981    581234     72817         NaN        27  12/8/11 10:33        0.0
# 538554    581408     85175         NaN        20  12/8/11 14:06        0.0
#
#         CustomerID         Country
# ...

# %% [markdown]
# there are 1454 null values

# %%
#replacing Nan value with ' '[whitespace]
df2["Description"].fillna(" ",inplace=True)

# %%
# crosschecking the Nan value
df2["Description"].isnull().sum()
# Out:
# 0

# %% [markdown]
# # Analysng InvoiceDate columns

# %%
df2["InvoiceDate"]=pd.to_datetime(df2["InvoiceDate"]).dt.date

# %%
df2.head(20)
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART          6
# 5     536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6     536365     21730    GLASS STAR FROSTED T LIGHT HOLDER         6
# 7     536366     22633               HAND WARMER UNION JACK         6
# 8     536366     22632            HAND WARMER RED POLKA DOT         6
# 9     536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
# 10    536367     22745           POPPY S PLAYHOUSE BEDROOM          6
# 11    536367     22748            POPPY S PLAYHOUSE KITCHEN         6
# ...

# %% [markdown]
# # checking total Null values in whole data set

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  541909 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   541909 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB
