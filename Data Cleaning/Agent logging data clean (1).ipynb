# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
from six.moves import urllib
import os

warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
df = pd.read_csv("AgentLogingReport.csv")
df
# Out:
#      SL No               Agent       Date Login Time Logout Time   Duration
# 0        1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39   02:04:10
# 1        2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16   00:00:17
# 2        3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35   00:45:06
# 4        5              Mukesh  30-Jul-22   14:03:15    15:11:52   01:08:36
# ..     ...                 ...        ...        ...         ...        ...
# 995    996        Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996    997             Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998      Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999        Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000               Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20
#
# [1000 rows x 6 columns]

# %%
df1 = df.copy()
df1
# Out:
#      SL No               Agent       Date Login Time Logout Time   Duration
# 0        1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39   02:04:10
# 1        2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16   00:00:17
# 2        3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35   00:45:06
# 4        5              Mukesh  30-Jul-22   14:03:15    15:11:52   01:08:36
# ..     ...                 ...        ...        ...         ...        ...
# 995    996        Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996    997             Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998      Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999        Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000               Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20
#
# [1000 rows x 6 columns]

# %%
df1.columns
# Out:
# Index(['SL No', 'Agent', 'Date', 'Login Time', 'Logout Time', 'Duration'], dtype='object')

# %%
df1.isnull().sum()
# Out:
# SL No          0
# Agent          0
# Date           0
# Login Time     0
# Logout Time    0
# Duration       0
# dtype: int64

# %%
df1["Agent"].nunique()
# Out:
# 49

# %%
df1["Agent"]
# Out:
# 0      Shivananda Sonwane
# 1          Khushboo Priya
# 2           Nandani Gupta
# 3         Hrisikesh Neogi
# 4                  Mukesh
#               ...
# 995          Manjunatha A
# 996               Bharath
# 997        Khushboo Priya
# 998          Nishtha Jain
# 999                 Tarun
# Name: Agent, Length: 1000, dtype: object

# %%
df1["Date"].isnull().sum()
# Out:
# 0

# %%
df1["Date"]
# Out:
# 0      30-Jul-22
# 1      30-Jul-22
# 2      30-Jul-22
# 3      30-Jul-22
# 4      30-Jul-22
#          ...
# 995    20-Jul-22
# 996    20-Jul-22
# 997    20-Jul-22
# 998    20-Jul-22
# 999    01-Jul-22
# Name: Date, Length: 1000, dtype: object

# %%
df1.tail(5)
# Out:
#      SL No           Agent       Date Login Time Logout Time   Duration
# 995    996    Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996    997         Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998  Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999    Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000           Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20

# %%
from datetime import datetime, timedelta

def convert_to_minutes(login_time, logout_time):
    # Convert time strings to datetime objects
    login_datetime = datetime.strptime(login_time, "%H:%M:%S")
    logout_datetime = datetime.strptime(logout_time, "%H:%M:%S")

    # Calculate duration
    duration = logout_datetime - login_datetime

    # Convert duration to minutes
    duration_minutes = duration.total_seconds() / 60

    return duration_minutes

# Example usage
login_time = "15:35:29"
logout_time = "17:39:39"
duration_minutes = convert_to_minutes(login_time, logout_time)

print(f"Duration in minutes: {duration_minutes:.2f} minutes")
# Out:
# Duration in minutes: 124.17 minutes

# %%
import pandas as pd
from datetime import datetime

# Load the CSV data into a DataFrame
df2 = pd.read_csv("AgentLogingReport.csv")

# Assuming your datetime information is in a column named 'Date_Time', adjust this accordingly
df2["Login Time"] = pd.to_datetime(df2["Login Time"], format='%H:%M:%S',errors='coerce')  

# Extract hour, minute, second, and millisecond into separate columns
df2['hour'] = df2["Login Time"].dt.hour
df2['minute'] = df2["Login Time"].dt.minute
df2['second'] = df2["Login Time"].dt.second
df2["total login time hr"] = df2['hour']+df2['minute']*0.0166667+df2["second"]*0.0166667*0.0166667

# Display the DataFrame with new columns
print(df2.head())
# Out:
#    SL No               Agent       Date          Login Time Logout Time  \
# 0      1  Shivananda Sonwane  30-Jul-22 1900-01-01 15:35:29    17:39:39
# 1      2      Khushboo Priya  30-Jul-22 1900-01-01 15:06:59    15:07:16
# 2      3       Nandani Gupta  30-Jul-22 1900-01-01 15:04:24    17:31:07
# 3      4     Hrisikesh Neogi  30-Jul-22 1900-01-01 14:34:29    15:19:35
# 4      5              Mukesh  30-Jul-22 1900-01-01 14:03:15    15:11:52
#
#    Duration  hour  minute  second  total login time hr
# 0  02:04:10    15      35      29            15.591390
# 1  00:00:17    15       6      59            15.116389
# 2  02:26:42    15       4      24            15.073333
# 3  00:45:06    14      34      29            14.574723
# 4  01:08:36    14       3      15            14.054167

# %%
df2
# Out:
#      SL No               Agent       Date          Login Time Logout Time  \
# 0        1  Shivananda Sonwane  30-Jul-22 1900-01-01 15:35:29    17:39:39
# 1        2      Khushboo Priya  30-Jul-22 1900-01-01 15:06:59    15:07:16
# 2        3       Nandani Gupta  30-Jul-22 1900-01-01 15:04:24    17:31:07
# 3        4     Hrisikesh Neogi  30-Jul-22 1900-01-01 14:34:29    15:19:35
# 4        5              Mukesh  30-Jul-22 1900-01-01 14:03:15    15:11:52
# ..     ...                 ...        ...                 ...         ...
# 995    996        Manjunatha A  20-Jul-22 1900-01-01 09:03:51    15:02:28
# 996    997             Bharath  20-Jul-22 1900-01-01 09:00:49    15:01:32
# 997    998      Khushboo Priya  20-Jul-22 1900-01-01 08:59:20    14:26:55
# 998    999        Nishtha Jain  20-Jul-22 1900-01-01 08:43:55    14:00:33
# 999   1000               Tarun  01-Jul-22 1900-01-01 01:52:47    12:01:07
#
#       Duration  hour  minute  second  total login time hr
# ...

# %%
# Assuming your datetime information is in a column named 'Date_Time', adjust this accordingly
df2["Login Time"] = pd.to_datetime(df2["Login Time"], format='%H:%M:%S',errors='coerce')  

# Extract hour, minute, second, and millisecond into separate columns
df2['hour'] = df2["Login Time"].dt.hour
df2['minute'] = df2["Login Time"].dt.minute
df2['second'] = df2["Login Time"].dt.second
df2["total login time hr"] = df2['hour']+df2['minute']*0.0166667+df2["second"]*0.0166667*0.0166667

# Assuming your datetime information is in a column named 'Date_Time', adjust this accordingly
df2["Logout Time"] = pd.to_datetime(df2["Logout Time"], format='%H:%M:%S',errors='coerce')  

# Extract hour, minute, second, and millisecond into separate columns
df2['hour1'] = df2["Logout Time"].dt.hour
df2['minute1'] = df2["Logout Time"].dt.minute
df2['second1'] = df2["Logout Time"].dt.second
df2["total logout time (hr)"] = df2['hour1']+df2['minute1']*0.0166667+df2["second1"]*0.0166667*0.0166667


# Assuming your datetime information is in a column named 'Date_Time', adjust this accordingly
df2["Duration"] = pd.to_datetime(df2["Duration"], format='%H:%M:%S',errors='coerce')  

# Extract hour, minute, second, and millisecond into separate columns
df2['hour2'] = df2["Duration"].dt.hour
df2['minute2'] = df2["Duration"].dt.minute
df2['second2'] = df2["Duration"].dt.second
df2["total Duration (hr)"] = df2['hour2']+df2['minute2']*0.0166667+df2["second2"]*0.0166667*0.0166667


# Display the DataFrame with new columns
print(df2.head())
# Out:
#    SL No               Agent       Date          Login Time  \
# 0      1  Shivananda Sonwane  30-Jul-22 1900-01-01 15:35:29
# 1      2      Khushboo Priya  30-Jul-22 1900-01-01 15:06:59
# 2      3       Nandani Gupta  30-Jul-22 1900-01-01 15:04:24
# 3      4     Hrisikesh Neogi  30-Jul-22 1900-01-01 14:34:29
# 4      5              Mukesh  30-Jul-22 1900-01-01 14:03:15
#
#           Logout Time            Duration  hour1  minute1  second1  \
# 0 1900-01-01 17:39:39 1900-01-01 02:04:10     17       39       39
# 1 1900-01-01 15:07:16 1900-01-01 00:00:17     15        7       16
# 2 1900-01-01 17:31:07 1900-01-01 02:26:42     17       31        7
# 3 1900-01-01 15:19:35 1900-01-01 00:45:06     15       19       35
# 4 1900-01-01 15:11:52 1900-01-01 01:08:36     15       11       52
#
#    total logout time (hr)  hour  minute  second  total login time hr  hour2  \
# 0               17.660835    15      35      29            15.591390    2.0
# ...

# %%
df2
# Out:
#      SL No               Agent       Date          Login Time  \
# 0        1  Shivananda Sonwane  30-Jul-22 1900-01-01 15:35:29
# 1        2      Khushboo Priya  30-Jul-22 1900-01-01 15:06:59
# 2        3       Nandani Gupta  30-Jul-22 1900-01-01 15:04:24
# 3        4     Hrisikesh Neogi  30-Jul-22 1900-01-01 14:34:29
# 4        5              Mukesh  30-Jul-22 1900-01-01 14:03:15
# ..     ...                 ...        ...                 ...
# 995    996        Manjunatha A  20-Jul-22 1900-01-01 09:03:51
# 996    997             Bharath  20-Jul-22 1900-01-01 09:00:49
# 997    998      Khushboo Priya  20-Jul-22 1900-01-01 08:59:20
# 998    999        Nishtha Jain  20-Jul-22 1900-01-01 08:43:55
# 999   1000               Tarun  01-Jul-22 1900-01-01 01:52:47
#
#             Logout Time            Duration  hour1  minute1  second1  \
# 0   1900-01-01 17:39:39 1900-01-01 02:04:10     17       39       39
# 1   1900-01-01 15:07:16 1900-01-01 00:00:17     15        7       16
# ...

# %%
df2
# Out:
#      SL No               Agent       Date          Login Time  \
# 0        1  Shivananda Sonwane  30-Jul-22 1900-01-01 15:35:29
# 1        2      Khushboo Priya  30-Jul-22 1900-01-01 15:06:59
# 2        3       Nandani Gupta  30-Jul-22 1900-01-01 15:04:24
# 3        4     Hrisikesh Neogi  30-Jul-22 1900-01-01 14:34:29
# 4        5              Mukesh  30-Jul-22 1900-01-01 14:03:15
# ..     ...                 ...        ...                 ...
# 995    996        Manjunatha A  20-Jul-22 1900-01-01 09:03:51
# 996    997             Bharath  20-Jul-22 1900-01-01 09:00:49
# 997    998      Khushboo Priya  20-Jul-22 1900-01-01 08:59:20
# 998    999        Nishtha Jain  20-Jul-22 1900-01-01 08:43:55
# 999   1000               Tarun  01-Jul-22 1900-01-01 01:52:47
#
#             Logout Time            Duration  hour1  minute1  second1  \
# 0   1900-01-01 17:39:39 1900-01-01 02:04:10     17       39       39
# 1   1900-01-01 15:07:16 1900-01-01 00:00:17     15        7       16
# ...

# %%
df2 = df2[["SL No","Agent","Date","Login Time","Logout Time","Duration","total logout time (hr)","total login time hr","total Duration (hr)"]]

# %%
df2
# Out:
#      SL No               Agent       Date          Login Time  \
# 0        1  Shivananda Sonwane  30-Jul-22 1900-01-01 15:35:29
# 1        2      Khushboo Priya  30-Jul-22 1900-01-01 15:06:59
# 2        3       Nandani Gupta  30-Jul-22 1900-01-01 15:04:24
# 3        4     Hrisikesh Neogi  30-Jul-22 1900-01-01 14:34:29
# 4        5              Mukesh  30-Jul-22 1900-01-01 14:03:15
# ..     ...                 ...        ...                 ...
# 995    996        Manjunatha A  20-Jul-22 1900-01-01 09:03:51
# 996    997             Bharath  20-Jul-22 1900-01-01 09:00:49
# 997    998      Khushboo Priya  20-Jul-22 1900-01-01 08:59:20
# 998    999        Nishtha Jain  20-Jul-22 1900-01-01 08:43:55
# 999   1000               Tarun  01-Jul-22 1900-01-01 01:52:47
#
#             Logout Time            Duration  total logout time (hr)  \
# 0   1900-01-01 17:39:39 1900-01-01 02:04:10               17.660835
# 1   1900-01-01 15:07:16 1900-01-01 00:00:17               15.121111
# ...

# %%
df2.isnull().sum()
# Out:
# SL No                     0
# Agent                     0
# Date                      0
# Login Time                0
# Logout Time               0
# Duration                  2
# total logout time (hr)    0
# total login time hr       0
# total Duration (hr)       2
# dtype: int64

# %%
df2["total Duration (hr)"].describe()
# Out:
# count    998.000000
# mean       1.644951
# std        2.286444
# min        0.001667
# 25%        0.045208
# 50%        0.383334
# 75%        2.369792
# max       20.686668
# Name: total Duration (hr), dtype: float64

# %%
df2[df2["total Duration (hr)"].isna()]
# Out:
#      SL No          Agent       Date          Login Time         Logout Time  \
# 557    558  Jaydeep Dixit  24-Jul-22 1900-01-01 20:52:20 1900-01-01 21:02:14
# 999   1000          Tarun  01-Jul-22 1900-01-01 01:52:47 1900-01-01 12:01:07
#
#     Duration  total logout time (hr)  total login time hr  total Duration (hr)
# 557      NaT               21.037222            20.872224                  NaN
# 999      NaT               12.018611             1.879724                  NaN

# %%
df2["total Duration (hr)"].fillna(1.644951,inplace=True)
df2
# Out:
#      SL No               Agent       Date          Login Time  \
# 0        1  Shivananda Sonwane  30-Jul-22 1900-01-01 15:35:29
# 1        2      Khushboo Priya  30-Jul-22 1900-01-01 15:06:59
# 2        3       Nandani Gupta  30-Jul-22 1900-01-01 15:04:24
# 3        4     Hrisikesh Neogi  30-Jul-22 1900-01-01 14:34:29
# 4        5              Mukesh  30-Jul-22 1900-01-01 14:03:15
# ..     ...                 ...        ...                 ...
# 995    996        Manjunatha A  20-Jul-22 1900-01-01 09:03:51
# 996    997             Bharath  20-Jul-22 1900-01-01 09:00:49
# 997    998      Khushboo Priya  20-Jul-22 1900-01-01 08:59:20
# 998    999        Nishtha Jain  20-Jul-22 1900-01-01 08:43:55
# 999   1000               Tarun  01-Jul-22 1900-01-01 01:52:47
#
#             Logout Time            Duration  total logout time (hr)  \
# 0   1900-01-01 17:39:39 1900-01-01 02:04:10               17.660835
# 1   1900-01-01 15:07:16 1900-01-01 00:00:17               15.121111
# ...

# %%
df2.isnull().sum()
# Out:
# SL No                     0
# Agent                     0
# Date                      0
# Login Time                0
# Logout Time               0
# Duration                  2
# total logout time (hr)    0
# total login time hr       0
# total Duration (hr)       0
# dtype: int64

# %%
df2["Duration"].fillna(0,inplace=True)
df2
# Out:
#      SL No               Agent       Date          Login Time  \
# 0        1  Shivananda Sonwane  30-Jul-22 1900-01-01 15:35:29
# 1        2      Khushboo Priya  30-Jul-22 1900-01-01 15:06:59
# 2        3       Nandani Gupta  30-Jul-22 1900-01-01 15:04:24
# 3        4     Hrisikesh Neogi  30-Jul-22 1900-01-01 14:34:29
# 4        5              Mukesh  30-Jul-22 1900-01-01 14:03:15
# ..     ...                 ...        ...                 ...
# 995    996        Manjunatha A  20-Jul-22 1900-01-01 09:03:51
# 996    997             Bharath  20-Jul-22 1900-01-01 09:00:49
# 997    998      Khushboo Priya  20-Jul-22 1900-01-01 08:59:20
# 998    999        Nishtha Jain  20-Jul-22 1900-01-01 08:43:55
# 999   1000               Tarun  01-Jul-22 1900-01-01 01:52:47
#
#             Logout Time             Duration  total logout time (hr)  \
# 0   1900-01-01 17:39:39  1900-01-01 02:04:10               17.660835
# 1   1900-01-01 15:07:16  1900-01-01 00:00:17               15.121111
# ...

# %%
df2.isnull().sum()
# Out:
# SL No                     0
# Agent                     0
# Date                      0
# Login Time                0
# Logout Time               0
# Duration                  0
# total logout time (hr)    0
# total login time hr       0
# total Duration (hr)       0
# dtype: int64

# %% [markdown]
# thus here we clean data by first checking each columns having null values and for better understanding we convert hours,minute and seconds into hours,hence we get two Na values thus we replaced na value to zero in description and also na values to mean in total duration columns
